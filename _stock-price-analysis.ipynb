# %%
# Import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandas_datareader.data import DataReader
import yfinance as yf
from pandas_datareader import data as pdr
from datetime import datetime
import os
import glob as glob

# %% [markdown]
# # Read in Raw Data

# %%
# This function reads the most recent dataset and cuts this based on the date range provided 

def cut_raw_data(start_date, end_date):
    
    # Set base path
    base_path = r'C:\Users\mball3\OneDrive - KPMG\Documents\Investment_Analysis\data'

    # This returns all folders in the base_path
    # return the folder, in the base path, if it is a folder
    # And only return folders of length 10 containins two underscores 
    folders = [folder for folder in os.listdir(base_path) if os.path.isdir(os.path.join(base_path, folder))
               and len(folder) == 10 and folder.count('_') == 2
              ]

    # Find latest folder in the path
    latest_folder = max(folders, key=lambda x: datetime.strptime(x,'%d_%m_%Y'))

    # Create new full path to the most recent folder
    latest_path = os.path.join(base_path, latest_folder)

    # Retrieve the file names
    filenames = glob.glob(latest_path+"/*.csv")

    # Combine data for all stocks
    all_data = []
    for filename in filenames:

        # Read in the historical data for each stock 
        historical_data = pd.read_csv(filename)
        Stock = filename.split("\\")[-1].split('.')[0]

        # Convert date to date format - english 
        historical_data['Stock'] = Stock
        historical_data['Date'] = pd.to_datetime(historical_data['Date'])

        historical_data.sort_values(by=['Date'], inplace=True)

        # Store the data
        all_data.append(historical_data)

    # Concatenate the data    
    df = pd.concat(all_data, ignore_index=True)

    # Convert date to date format 
    df['Date'] = pd.to_datetime(df['Date'])
    df.sort_values(by=['Date'], inplace=True)
    
    # Cut by dates
    df = df[(df['Date'] > start_date) & (df['Date'] < end_date) ]

    # Set the date as the index
    df = df.set_index('Date')

    # make certain columns numeric 
    cols_to_convert = ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
    df[cols_to_convert] = df[cols_to_convert].apply(pd.to_numeric, errors='coerce')

    # Confirm column names
    df.columns = ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'Stock']
    
    return df

# %%
# This is the date range I had initally analysed
# It was just over a year's worth of data from the first data i began my analysis
df = cut_raw_data(start_date='1989-12-31', end_date='2024-01-15')
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1990-01-02    0.605903    0.616319    0.598090    0.616319    0.382096
# 1990-01-02    0.314732    0.334821    0.312500    0.332589    0.263414
# 1990-01-02    0.000000    1.277778    1.194444    1.250000    1.083150
# 1990-01-02    0.000000    0.570313    0.546875    0.546875    0.537054
# 1990-01-03    0.621528    0.626736    0.614583    0.619792    0.384249
# ...                ...         ...         ...         ...         ...
# 2024-01-12   85.879997   86.449997   85.639999   86.379997   86.379997
# 2024-01-12  144.339996  144.740005  143.360001  144.240005  144.240005
# 2024-01-12  760.729980  763.349976  754.859985  759.669983  759.669983
# 2024-01-12   47.970001   47.970001   47.380001   47.570000   47.570000
# 2024-01-12   36.880001   37.349998   36.869999   36.930000   36.930000
#
#                Volume  Stock
# Date
# 1990-01-02   53035200   MSFT
# 1990-01-02  183198400   AAPL
# 1990-01-02     931050   LRCX
# 1990-01-02     209600     EA
# 1990-01-03  113774400   MSFT
# ...               ...    ...
# 2024-01-12    5883900   GILD
# 2024-01-12   13995200   GOOG
# 2024-01-12     497200   LRCX
# 2024-01-12    3672300   CPRT
# 2024-01-12    1558600  TCEHY
#
# [75033 rows x 7 columns]

# %%
# Now convert the one large dataframe into seperate dfs for each stock
stocks = df['Stock'].unique()

for stock in stocks:
    globals()[f"{stock}"] = df[df['Stock'] == stock].drop('Stock',axis=1)

# %%
AAPL
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1990-01-02    0.314732    0.334821    0.312500    0.332589    0.263414
# 1990-01-03    0.339286    0.339286    0.334821    0.334821    0.265181
# 1990-01-04    0.341518    0.345982    0.332589    0.335938    0.266066
# 1990-01-05    0.337054    0.341518    0.330357    0.337054    0.266950
# 1990-01-08    0.334821    0.339286    0.330357    0.339286    0.268718
# ...                ...         ...         ...         ...         ...
# 2024-01-08  182.089996  185.600006  181.500000  185.559998  185.559998
# 2024-01-09  183.919998  185.149994  182.729996  185.139999  185.139999
# 2024-01-10  184.350006  186.399994  183.919998  186.190002  186.190002
# 2024-01-11  186.539993  187.050003  183.619995  185.589996  185.589996
# 2024-01-12  186.059998  186.740005  185.190002  185.919998  185.919998
#
#                Volume
# Date
# 1990-01-02  183198400
# 1990-01-03  207995200
# 1990-01-04  221513600
# 1990-01-05  123312000
# 1990-01-08  101572800
# ...               ...
# 2024-01-08   59144500
# 2024-01-09   42841800
# 2024-01-10   46792900
# 2024-01-11   49128400
# 2024-01-12   40444700
#
# [8574 rows x 6 columns]

# %%
# Inspect one stocks data 
AAPL.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  8574.000000  8574.000000  8574.000000  8574.000000  8574.000000
# mean     25.529468    25.808005    25.261573    25.546925    24.608634
# std      46.040452    46.547184    45.568534    46.082971    45.733197
# min       0.114955     0.118304     0.113839     0.115513     0.097918
# 25%       0.377232     0.383929     0.368304     0.377232     0.314688
# 50%       3.047321     3.086607     3.016964     3.047857     2.583607
# 75%      27.026875    27.236874    26.759375    27.005625    24.568556
# max     198.020004   199.619995   197.000000   198.110001   198.110001
#
#              Volume
# count  8.574000e+03
# mean   3.640528e+08
# std    3.596948e+08
# min    2.396800e+06
# 25%    1.319556e+08
# 50%    2.453882e+08
# 75%    4.590096e+08
# max    7.421641e+09

# %% [markdown]
# Description of each variable:
#
# Open - opening price that day
#
# High - highest value that day
#
# Low - lowest price that day
#
# Close - close price that day
#
# Adj Close - close price adjusted for splits and dividend distributions
#
# Volume - number of trades made that day
#
#
# What is notable from the above description data
# - the close price on average is marginally higher than the open price
# - the close price also has a slightly smaller standard deviation,
#   meaning there is less veriance in the price of this stock at close
#       - but the open price is just the previous days close price, so perhaps this is meaningless
#
# - the median < mean for volume, meaning there is a positive skew for the volume of trades
#     - this means that the volume of transactions of AAPL are more often less than the mean number
#     - there are more days of lower trade volume than the mean
#
# - the variance of the high price is lower than of the low price,
#     - meaning the price fluctuations of spikes are slightly lower than of a dips

# %%
# Have a look at the info
AAPL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8574 entries, 1990-01-02 to 2024-01-12
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       8574 non-null   float64
#  1   High       8574 non-null   float64
#  2   Low        8574 non-null   float64
#  3   Close      8574 non-null   float64
#  4   Adj Close  8574 non-null   float64
#  5   Volume     8574 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 468.9 KB

# %% [markdown]
# # 1. Data Visualisation

# %% [markdown]
# <style>
#     .my-custom-font {
#         font-size: 16px;
#     }
# </style>
#
# <span class="my-custom-font">
#
#
# First I will visualise the closing price of stocks.
#
# The adjusted stock price is regarded as the best indicator of a stock's value
#
# </span>

# %%
def line_plot(data, column, col_name, start_date, end_date):
    
    data = data[(data.index > start_date) & (data.index < end_date)]
    
    # Set Style 
    sns.set(style="whitegrid")

    # Create subplots
    plt.figure(figsize=(15, 10))
    plt.subplots_adjust(top=1.25, bottom=1.2)

    # Vis for each stock
    stocks = sorted(data['Stock'].unique())

    for i, stock in enumerate(stocks, 1):
        subset = data[data['Stock'] == stock]
        plt.subplot(6,2, i)
        sns.lineplot(x=subset.index, y=subset[column], data=subset)
        plt.title(f'{stock}', fontsize=10)
        plt.xlabel(None)
        plt.xticks(fontsize=10)
        plt.ylabel(col_name, fontsize=10)
        plt.yticks(fontsize=10)

    #plt.subplots_adjust(hspace=100)

    plt.tight_layout()
    plt.show()

# %%
line_plot(df, 'Adj Close', 'Adj Close Price ($US)', start_date = '2022-12-31', end_date = '2024-01-15')

# %% [markdown]
# - TCEHY has had a fairy steady fall in value over the period
# - META, LRCX, CPRT, AAPL & AMZN have shown increasing valuations
# - What I find most interesting, is the lack in volatility of META's price rise, this apprears to be steady growth
# - Whereas SNOW for example shows high volatility - this may make predicing this stocks price changes more difficult
# - But I anticipate that there could be overfitting when predicting META's stock price

# %% [markdown]
# Below I have visualised the volume of trades, that is the number of times this stock is traded on a daily basis

# %%
line_plot(df, 'Volume', 'Volume (% of 100,000)', start_date = '2022-12-31', end_date = '2024-01-15')

# %% [markdown]
# - AAPL and AMZN show the most obvious decline in volume of trades
# - TCEHY has had an interesting spike around Q4 2023

# %% [markdown]
# # 3. Look at the Cost Basis - Profitability

# %% [markdown]
# I intend on making a profit from my analysis, therefore it will be worth visualising the daily profit from each stock
#
# One way is to calculate the profit or loss on a daily basis.
#
# I do this by calculating the cost basis, which measures the percentage change in the stock price from one day to the next

# %%
def create_daily_return(data):
    
    stocks = sorted(data['Stock'].unique())

    df_update = []

    for stock in stocks:
        temp = data[data['Stock']==stock]
        temp = temp.sort_index()
        temp['Daily Return'] = temp['Adj Close'].pct_change()
        df_update.append(temp)

    df2=pd.concat(df_update)

    cols_to_convert = ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']

    df2[cols_to_convert] = df2[cols_to_convert].apply(pd.to_numeric, errors='coerce')
    
    return df2

# %%
df2 = create_daily_return(df)

# %%
line_plot(df2, 'Daily Return', 'Daily Return', start_date = '2022-12-31', end_date = '2024-01-15')

# %% [markdown]
# - where values are greater than 0, the stock is making a profit for that day
# - clearly profitability is extremely volatile, thus highlighting my theory that me being able to profit from this excercise is unlikely
# - META shows a good example of where a shock has massively altered the price of a stock from one day to the next

# %% [markdown]
# Lets not look at the spread of profitability for each stock

# %%
def hisogram_plot(data, column, bins, start_date, end_date):
    
    data = data[(data.index > start_date) & (data.index < end_date)]
    
    # Set Style 
    sns.set(style="whitegrid")

    # Create subplots
    plt.figure(figsize=(15, 10))
    plt.subplots_adjust(top=1.25, bottom=1.2)

    # Vis for each stock
    stocks = sorted(data['Stock'].unique())

    for i, stock in enumerate(stocks, 1):
        subset = data[data['Stock'] == stock]
        subset = subset[~subset[column].isna()]
        plt.subplot(6,2, i)
        sns.histplot(data=subset, x=column, bins=bins)
        plt.title(f'{stock}', fontsize=10)
        plt.xlabel(column, fontsize=10)
        plt.xticks(fontsize=10)
        plt.ylabel('Count', fontsize=10)
        plt.yticks(fontsize=10)

    #plt.subplots_adjust(hspace=100)

    plt.tight_layout()
    plt.show()

# %%
hisogram_plot(df2, 'Daily Return', 50, start_date = '2022-12-31', end_date = '2024-01-15')

# %% [markdown]
# - the spread of profitability for GILD is interesting, it has a very even distribution
# - as does LRCX
# - CPRT has very few days of high return
# - EA appears to have the lowest variance around the mean
# - most stocks appear to have a fairly even spread, with a mean around zero
# - this would suggest that it is likely to be difficult to make profit from trading these stocks as on average they will make no return from one day to the next

# %% [markdown]
# # 4. Moving Averages

# %% [markdown]
# - I want to better understand the trend of prices
# - To do this, I will create moving averages for each stock
# - This smooths out the trends and may make it easier for me to see more general price changes for these stocks

# %%
# I ignore the warnings here, because they are just warning me that I am creating new columns on a copy of the original data
# I am aware of this
import warnings
warnings.filterwarnings('ignore')

# I will begin by working out the moving averages for the original data
ma = [10, 20, 30, 50, 200]
stocks = sorted(df2['Stock'].unique())

df_update = []

for stock in stocks:
    temp = df2[df2['Stock']==stock]
    for m in ma:
        temp[f'ac_ma_{m}'] = temp['Adj Close'].rolling(m).mean()
    df_update.append(temp)

# Join data together
df3 = pd.concat(df_update)

# Remove column names that are in rows, due to concatenation
cols_to_convert = ['Open', 'High', 'Low', 'Close', 'Adj Close', 
                   'Volume', 'Daily Return', 'ac_ma_10', 
                   'ac_ma_20', 'ac_ma_30', 'ac_ma_50', 'ac_ma_200']

df3[cols_to_convert] = df3[cols_to_convert].apply(pd.to_numeric, errors='coerce')

df3 = df3[['Stock', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 
          'Daily Return', 'ac_ma_10', 
           'ac_ma_20', 'ac_ma_30', 'ac_ma_50', 'ac_ma_200']]
df3 = df3.sort_index()    


print(f"This should return True, :{len(df3) == len(df2) == len(df)}")
# Out:
# This should return True, :True

# %%
# Check for duplicates, this should be empty 
duplicate_rows = df3[df3.duplicated()]

duplicate_rows
# Out:
# Empty DataFrame
# Columns: [Stock, Open, High, Low, Close, Adj Close, Volume, Daily Return, ac_ma_10, ac_ma_20, ac_ma_30, ac_ma_50, ac_ma_200]
# Index: []

# %%
# Now convert the one large dataframe into seperate dfs for each stock
stocks = sorted(df3['Stock'].unique())

for stock in stocks:
    globals()[f"{stock}"] = df3[df3['Stock'] == stock].drop('Stock',axis=1)

# %%
AAPL.tail(3)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-01-10  184.350006  186.399994  183.919998  186.190002  186.190002
# 2024-01-11  186.539993  187.050003  183.619995  185.589996  185.589996
# 2024-01-12  186.059998  186.740005  185.190002  185.919998  185.919998
#
#               Volume  Daily Return    ac_ma_10    ac_ma_20    ac_ma_30  \
# Date
# 2024-01-10  46792900      0.005671  186.912999  191.323501  191.525334
# 2024-01-11  49128400     -0.003223  186.156999  190.867500  191.365000
# 2024-01-12  40444700      0.001778  185.390999  190.265500  191.250001
#
#               ac_ma_50   ac_ma_200
# Date
# 2024-01-10  188.369413  180.076908
# 2024-01-11  188.679894  180.216655
# 2024-01-12  188.987388  180.361190

# %%
# I have not plotted them as subplots in order to make them easier to visualise

# Set Style 
sns.set(style="whitegrid")

# Create subplots
plt.figure(figsize=(20, 20))

AAPL[['Adj Close', 'ac_ma_10', 'ac_ma_20', 'ac_ma_30', 'ac_ma_50', 'ac_ma_200']].plot()
plt.title('AAPL', fontsize=10)
plt.xlabel(None)
plt.xticks(fontsize=10)
plt.ylabel('Price ($)', fontsize=10)
plt.yticks(fontsize=10)


AMZN[['Adj Close', 'ac_ma_10', 'ac_ma_20', 'ac_ma_30', 'ac_ma_50', 'ac_ma_200']].plot()
plt.title('AMZN', fontsize=10)
plt.xlabel(None)
plt.xticks(fontsize=10)
plt.ylabel('Price ($)', fontsize=10)
plt.yticks(fontsize=10)

CPRT[['Adj Close', 'ac_ma_10', 'ac_ma_20', 'ac_ma_30', 'ac_ma_50', 'ac_ma_200']].plot()
plt.title('CPRT', fontsize=10)
plt.xlabel(None)
plt.xticks(fontsize=10)
plt.ylabel('Price ($)', fontsize=10)
plt.yticks(fontsize=10)

EA[['Adj Close', 'ac_ma_10', 'ac_ma_20', 'ac_ma_30', 'ac_ma_50', 'ac_ma_200']].plot()
plt.title('EA', fontsize=10)
plt.xlabel(None)
plt.xticks(fontsize=10)
plt.ylabel('Price ($)', fontsize=10)
plt.yticks(fontsize=10)

GILD[['Adj Close', 'ac_ma_10', 'ac_ma_20', 'ac_ma_30', 'ac_ma_50', 'ac_ma_200']].plot()
plt.title('GILD', fontsize=10)
plt.xlabel(None)
plt.xticks(fontsize=10)
plt.ylabel('Price ($)', fontsize=10)
plt.yticks(fontsize=10)

GOOG[['Adj Close', 'ac_ma_10', 'ac_ma_20', 'ac_ma_30']].plot()
plt.title('GOOG', fontsize=10)
plt.xlabel(None)
plt.xticks(fontsize=10)
plt.ylabel('Price ($)', fontsize=10)
plt.yticks(fontsize=10)

LRCX[['Adj Close', 'ac_ma_10', 'ac_ma_20', 'ac_ma_30', 'ac_ma_50', 'ac_ma_200']].plot()
plt.title('LRCX', fontsize=10)
plt.xlabel(None)
plt.xticks(fontsize=10)
plt.ylabel('Price ($)', fontsize=10)
plt.yticks(fontsize=10)

META[['Adj Close', 'ac_ma_10', 'ac_ma_20', 'ac_ma_30', 'ac_ma_50', 'ac_ma_200']].plot()
plt.title('META', fontsize=10)
plt.xlabel(None)
plt.xticks(fontsize=10)
plt.ylabel('Price ($)', fontsize=10)
plt.yticks(fontsize=10)

MSFT[['Adj Close', 'ac_ma_10', 'ac_ma_20', 'ac_ma_30', 'ac_ma_50', 'ac_ma_200']].plot()
plt.title('MSFT', fontsize=10)
plt.xlabel(None)
plt.xticks(fontsize=10)
plt.ylabel('Price ($)', fontsize=10)
plt.yticks(fontsize=10)

NVDA[['Adj Close', 'ac_ma_10', 'ac_ma_20', 'ac_ma_30', 'ac_ma_50', 'ac_ma_200']].plot()
plt.title('NVDA', fontsize=10)
plt.xlabel(None)
plt.xticks(fontsize=10)
plt.ylabel('Price ($)', fontsize=10)
plt.yticks(fontsize=10)

SNOW[['Adj Close', 'ac_ma_10', 'ac_ma_20', 'ac_ma_30', 'ac_ma_50', 'ac_ma_200']].plot()
plt.title('SNOW', fontsize=10)
plt.xlabel(None)
plt.xticks(fontsize=10)
plt.ylabel('Price ($)', fontsize=10)
plt.yticks(fontsize=10)

TCEHY[['Adj Close', 'ac_ma_10', 'ac_ma_20', 'ac_ma_30', 'ac_ma_50', 'ac_ma_200']].plot()
plt.title('TCEHY', fontsize=10)
plt.xlabel(None)
plt.xticks(fontsize=10)
plt.ylabel('Price ($)', fontsize=10)
plt.yticks(fontsize=10)
# Out:
# (array([-20.,   0.,  20.,  40.,  60.,  80., 100.]),
#  [Text(0, -20.0, '−20'),
#   Text(0, 0.0, '0'),
#   Text(0, 20.0, '20'),
#   Text(0, 40.0, '40'),
#   Text(0, 60.0, '60'),
#   Text(0, 80.0, '80'),
#   Text(0, 100.0, '100')])

# %% [markdown]
# - The moving averages are a useful way to understand the trend of each stock
# - The most common trend for these stock prices is that over time the are increasing, with the exception of SNOW
# - I therefore anticipate that my model will predict stock prices to rise
# - Given the stock prices are increasing at an increasing rate, I need to make sure I cut my training data to a recent period
# - Failure to do so will mean any model will just predict prices to rise

# %% [markdown]
# # 5. Correlations

# %% [markdown]
# - I will now look at the correlations between the stock's daily returns
# - This is to understand whether stocks in the same industry behave in a similar fashion
# - If we see that this is the case, I may be able to use price changes to one stock as indicators for future price changes in another stock

# %%
def correlation_plots(column_name, start_date, end_date):
    
    # TAKE THE FAILY RETURN FROM INDIVINDUAL DATAFRAMES
    # COMBINE INTO ONE DATASET
    stocks = sorted(df3['Stock'].unique())
    stocks_df = [AAPL, AMZN, CPRT, EA, GILD, GOOG, LRCX, META, MSFT, NVDA, SNOW, TCEHY]

    data_store = pd.DataFrame()
    for stock, s_df in zip(stocks, stocks_df):
        temp_store = pd.Series(s_df[column_name], name=f'{stock}')
        data_store = pd.concat([data_store, temp_store], axis=1)

    # Make a copy  
    df = data_store
    df.reset_index(inplace=True)
    df['index'] = pd.to_datetime(df['index'])
    df = df.set_index(df['index'])
    df.drop(columns=['index'], inplace=True)
    
    df = df[(df.index > start_date) & (df.index < end_date)]
    
    # PLOT A CORRELATION HEATMAP
    correlation_matrix = df.corr()

    # Create a heatmap
    plt.figure(figsize=(6, 6))
    sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5, annot_kws={"size": 8})
    plt.title(f'{column_name} Correlation Matrix Heatmap')
    plt.show()
    
    # CREATE PAIRPLOT
    big_5_dr = df[['AAPL', 'AMZN', 'GOOG', 'META','MSFT']]
    
    daily_return = sns.pairplot(big_5_dr)
    daily_return.map_lower(sns.kdeplot, levels=4, color=".2")
    plt.suptitle(f"Pairplot of {column_name}", y=1.02)
    
    return df

# %%
dr_df = correlation_plots('Daily Return', start_date = '2022-12-31', end_date = '2024-01-15')

# %% [markdown]
# As of 15/01/2024:
# - the strongest correlation is between GOOG & AMZN - two massive tech companies, so this makes logical sense
# - then GOOG & META
# - then META & AZN and MSFT & AMZN
# - my assumption is that because these 5 massive tech companies are so much larger than the rest of the stocks I am looking at, they are most similar to eachother
#     - and so shocks to the market affect them in similar ways
#     - or perhaps a fall in the value of one of these stocks, may impact the value of the others
#
#
# I then investigate the correlations between the top 5 tech companies in more detail:
# - we already know from the heatmap that the correlations between the big 5 tech companies are all positive
# - we also know which are strongest
# - but this is a useful way of visualising the relationships
#
#
# - the Kernel density plot has been useful for showing the three most dense areas in this distribution

# %% [markdown]
# I'm going to repeat this process for the adjusted closing price too

# %%
ac_df = correlation_plots('Adj Close', start_date = '2022-12-31', end_date = '2024-01-15')

# %% [markdown]
# - From this we can see that the correlations between the adjusted closing prices of these stocks are far stronger than they are for the daily return
# - this suggests that closing price changes for the big 5 tech companies are much more aligned than the daily returns are
# - the daily returns are likely to be less well correlated because they refer to a percentage change from one point to another, which involves two prices, instead of just one
#
# - analysing the correlations between these companies has beenn useful in my understanding of these companies
# - though it isn't influencing how I will conduct my analyis at this point

# %% [markdown]
# # 6. Risk vs. Reward

# %% [markdown]
# I've seen an example online where someone used the mean and standard deviation of a stock price  to represent the reward and risk of each stock
# - I believe that the mean of the daily return is used to represent the expected return from a stock
#     - it is the average % profit earnt on a stock
#
# - The standard deviation was used as a measure of risk
#     - this is because the standard deviation measures the variability of a stock
#     - a large standard deviation means there is lots of variance about the mean of a stocks daily return

# %%
# Find the mean and standard deviation for each stock
col_df = []
mean_df = []
std_df = []
for col in dr_df.columns:
    mean = dr_df[col].mean()
    std = dr_df[col].std()
    
    col_df.append(col)
    mean_df.append(mean)
    std_df.append(std)
    
er_risk = {'stock':col_df, 'mean':mean_df, 'std':std_df}
er_risk = pd.DataFrame(er_risk)
er_risk
# Out:
#     stock      mean       std
# 0    AAPL  0.001489  0.012910
# 1    AMZN  0.002570  0.020643
# 2    CPRT  0.001816  0.013610
# 3      EA  0.000574  0.012722
# 4    GILD  0.000253  0.012879
# 5    GOOG  0.002059  0.019035
# 6    LRCX  0.002583  0.022439
# 7    META  0.004684  0.024858
# 8    MSFT  0.002019  0.015637
# 9    NVDA  0.005550  0.030335
# 10   SNOW  0.001691  0.033986
# 11  TCEHY -0.000014  0.024073

# %%
# plot the expected return against the risk of each stock
sns.scatterplot(data=er_risk, x='mean', y='std')

for index, row in er_risk.iterrows():
    plt.annotate(row['stock'], 
                 (row['mean'], row['std']), 
                 textcoords="offset points", 
                 xytext=(0, 5), 
                 ha='center',
                 fontsize=8)
    
plt.xlabel('Expected Return')
plt.ylabel('Risk')
# Out:
# Text(0, 0.5, 'Risk')

# %% [markdown]
# - unbelieveably the expected return from each stock is positive, meaning that on average the price of each stock is higher than the day before on average
# - based on this, we should place money on every stock and will make profit on average
#
#
#
# - given that the expected return from this period is highest for NVDA, I am going to try and predict it's stock price going forward
# - this is the next step of my analysis

# %% [markdown]
# # 7. LSTM Modelling

# %% [markdown]
# - I have seen that the LSTM model is a really useful model for timeseries forecasting
# - I am going to test this model first and may try some different types too
# - My analysis for far has informed me that I will be predicting the price of the NVDA stock
# - I will be predicting the Close price, not the Adjusted price, as I cannot account for tax/dividends fees etc
# - My analysis so far has also taught me that stock prices have risen sharpl in recent years
# - I therefore need to cuy my data so as not to train my model on old trends, which may introduce BIAS into my model

# %% [markdown]
# *Getting the raw data*

# %%
df = cut_raw_data(start_date='2022-12-31', end_date='2024-01-15')

stocks = df['Stock'].unique()

for stock in stocks:
    globals()[f"{stock}"] = df[df['Stock'] == stock].drop('Stock',axis=1)

    
NVDA.tail(3)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-01-10  536.159973  546.000000  534.890015  543.500000  543.500000
# 2024-01-11  549.989990  553.460022  535.599976  548.219971  548.219971
# 2024-01-12  546.200012  549.700012  543.299988  547.099976  547.099976
#
#               Volume
# Date
# 2024-01-10  53379600
# 2024-01-11  59675900
# 2024-01-12  35247900

# %%
# This function looks at the close price on a given date
# If the window is say 3
# It then finds the close price three days prior to this date
# So Target-1 is yesterdays close price
# This turns this into a supervised learning problem, where Target is the target variable
# And the other n variables are the input data
# This is to get the dataset required for the LSTM model

def create_window_df(data, window):
    # Create temp data between date range specified
    temp = data.loc[data.index[0]:data.index[-1]]
    
    df_window = []
    
    for i in range(len(temp)):
        row = temp[i-window:i+1]
        
        if len(row) != (window+1):
            continue
            
        else:
            date = row.index[-1]
            column_names = [f'Target-{j}' for j in range(window, 0, -1)]
            column_names.append('Target')
            
            df_dict = dict(zip(column_names, row))
            df_dict.update({'Date':date})
            
            df_window.append(df_dict)
    
    df_window = pd.DataFrame(df_window)
    df_window = df_window.set_index('Date')
    
    return df_window

# %%
data_set = NVDA
df_windowed = create_window_df(data_set['Close'], window=3)
df_windowed
# Out:
#               Target-3    Target-2    Target-1      Target
# Date
# 2023-01-06  143.149994  147.490005  142.649994  148.589996
# 2023-01-09  147.490005  142.649994  148.589996  156.279999
# 2023-01-10  142.649994  148.589996  156.279999  159.089996
# 2023-01-11  148.589996  156.279999  159.089996  160.009995
# 2023-01-12  156.279999  159.089996  160.009995  165.110001
# ...                ...         ...         ...         ...
# 2024-01-08  475.690002  479.980011  490.970001  522.530029
# 2024-01-09  479.980011  490.970001  522.530029  531.400024
# 2024-01-10  490.970001  522.530029  531.400024  543.500000
# 2024-01-11  522.530029  531.400024  543.500000  548.219971
# 2024-01-12  531.400024  543.500000  548.219971  547.099976
#
# [256 rows x 4 columns]

# %%
# Turn this data into a numpy dataset, for the model

def windowed_to_numpy(data):
    
    data = data.reset_index()
    data_as_np = data.to_numpy()
    
    # Get just the dates
    dates = data_as_np[:, 0]

    # Find the x data, then need to get the data in one entry 
    # This seems to be the desired shape for the model
    middle_matrix = data_as_np[:, 1:4]
    X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

    # Get the target data
    Y = data_as_np[:, 4]
    
    return dates, X.astype(np.float32), Y.astype(np.float32)

# %%
dates, X, Y = windowed_to_numpy(df_windowed)

dates.shape, X.shape, Y.shape
# Out:
# ((256,), (256, 3, 1), (256,))

# %% [markdown]
# *Train, Validation, Test split*
#
# - I want to create a training, evaluation and a test dataset
# - so rather than creating that with the train_test_split function, im going to create it manually

# %%
q_80 = int(len(dates) *.8)
q_90 = int(len(dates) *.9)

#Train
dates_train, X_train, Y_train = dates[:q_80], X[:q_80], Y[:q_80]

#Eval
dates_val, X_val, Y_val = dates[q_80:q_90], X[q_80:q_90], Y[q_80:q_90]

#Test
dates_test, X_test, Y_test = dates[q_90:], X[q_90:], Y[q_90:]

# Plot
plt.plot(dates_train, Y_train)
plt.plot(dates_val, Y_val)
plt.plot(dates_test, Y_test)
plt.legend(['Train', 'Val', 'Test'])
plt.ylabel('Close Price ($)')
# Out:
# Text(0, 0.5, 'Close Price ($)')

# %% [markdown]
# *Building the model*

# %%
from tensorflow.keras.models import Sequential # model
from tensorflow.keras.optimizers import Adam #optimiser
from tensorflow.keras import layers # model will have multiple layers

# Build

model = Sequential([layers.Input((3,1)), # there are three layers to out input data, because the window has three layers
                   layers.LSTM(64), # number of nuerons in the neural network - this is a good level to prevent overfitting 
                   layers.Dense(32, activation='relu'), # this creates another layer in the NN
                   layers.Dense(32, activation='relu'), # do another
                   layers.Dense(1) # final layer
                   ])

model.compile(loss='mse', # loss means we are trying to minimise the mean squared error
              optimizer=Adam(learning_rate=0.001), # try this learning rate
              metrics = ['mean_absolute_error'] # this allows us to see on average how off the model is
                                                # it makes more sense to interpret this, even if minimising the mean squared error
             )


model.fit(X_train, Y_train, validation_data=(X_val, Y_val), epochs=100 ) # runs for 100 times on the training data
# Out:
# WARNING:tensorflow:From C:\Users\mball3\AppData\Local\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\mball3\AppData\Local\anaconda3\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\mball3\AppData\Local\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\mball3\AppData\Local\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 7/7 [==============================] - 5s 148ms/step - loss: 129765.9219 - mean_absolute_error: 345.4907 - val_loss: 219689.8125 - val_mean_absolute_error: 468.0141
# Epoch 2/100
# 7/7 [==============================] - 0s 12ms/step - loss: 129351.8750 - mean_absolute_error: 344.8952 - val_loss: 219088.7500 - val_mean_absolute_error: 467.3718
# Epoch 3/100
# 7/7 [==============================] - 0s 12ms/step - loss: 128931.2656 - mean_absolute_error: 344.2850 - val_loss: 218550.3438 - val_mean_absolute_error: 466.7953
# Epoch 4/100
# 7/7 [==============================] - 0s 10ms/step - loss: 128488.5625 - mean_absolute_error: 343.6417 - val_loss: 217842.1094 - val_mean_absolute_error: 466.0362
# Epoch 5/100
# 7/7 [==============================] - 0s 10ms/step - loss: 127923.0000 - mean_absolute_error: 342.8091 - val_loss: 216979.9844 - val_mean_absolute_error: 465.1098
# Epoch 6/100
# 7/7 [==============================] - 0s 9ms/step - loss: 127118.4297 - mean_absolute_error: 341.6339 - val_loss: 215492.6719 - val_mean_absolute_error: 463.5084
# Epoch 7/100
# 7/7 [==============================] - 0s 11ms/step - loss: 125875.5469 - mean_absolute_error: 339.7970 - val_loss: 213467.0938 - val_mean_absolute_error: 461.3179
# Epoch 8/100
# 7/7 [==============================] - 0s 21ms/step - loss: 124269.3203 - mean_absolute_error: 337.4466 - val_loss: 211172.4219 - val_mean_absolute_error: 458.8245
# Epoch 9/100
# 7/7 [==============================] - 0s 20ms/step - loss: 122578.5000 - mean_absolute_error: 334.9016 - val_loss: 208628.9844 - val_mean_absolute_error: 456.0439
# Epoch 10/100
# 7/7 [==============================] - 0s 10ms/step - loss: 120435.5000 - mean_absolute_error: 331.7249 - val_loss: 205112.1875 - val_mean_absolute_error: 452.1725
# Epoch 11/100
# 7/7 [==============================] - 0s 21ms/step - loss: 117737.5000 - mean_absolute_error: 327.6418 - val_loss: 201134.8906 - val_mean_absolute_error: 447.7523
# Epoch 12/100
# 7/7 [==============================] - 0s 12ms/step - loss: 114565.0625 - mean_absolute_error: 322.5997 - val_loss: 195819.2500 - val_mean_absolute_error: 441.7731
# Epoch 13/100
# 7/7 [==============================] - 0s 13ms/step - loss: 110128.3516 - mean_absolute_error: 315.7345 - val_loss: 189279.1094 - val_mean_absolute_error: 434.3104
# Epoch 14/100
# 7/7 [==============================] - 0s 22ms/step - loss: 105313.1797 - mean_absolute_error: 308.0217 - val_loss: 181943.2656 - val_mean_absolute_error: 425.7822
# Epoch 15/100
# 7/7 [==============================] - 0s 21ms/step - loss: 99917.4766 - mean_absolute_error: 299.0123 - val_loss: 173715.8906 - val_mean_absolute_error: 416.0019
# Epoch 16/100
# 7/7 [==============================] - 0s 23ms/step - loss: 93172.1406 - mean_absolute_error: 287.3888 - val_loss: 162930.1094 - val_mean_absolute_error: 402.8345
# Epoch 17/100
# 7/7 [==============================] - 0s 13ms/step - loss: 85972.1016 - mean_absolute_error: 274.7902 - val_loss: 152542.6250 - val_mean_absolute_error: 389.7310
# Epoch 18/100
# 7/7 [==============================] - 0s 11ms/step - loss: 78847.7422 - mean_absolute_error: 261.6236 - val_loss: 141911.9688 - val_mean_absolute_error: 375.8452
# Epoch 19/100
# 7/7 [==============================] - 0s 10ms/step - loss: 71507.5547 - mean_absolute_error: 247.1788 - val_loss: 130654.0547 - val_mean_absolute_error: 360.5575
# Epoch 20/100
# 7/7 [==============================] - 0s 9ms/step - loss: 63994.0742 - mean_absolute_error: 231.3878 - val_loss: 118987.8281 - val_mean_absolute_error: 343.9991
# Epoch 21/100
# 7/7 [==============================] - 0s 10ms/step - loss: 56402.5039 - mean_absolute_error: 214.3400 - val_loss: 107145.8828 - val_mean_absolute_error: 326.3328
# Epoch 22/100
# 7/7 [==============================] - 0s 9ms/step - loss: 48776.8203 - mean_absolute_error: 195.5810 - val_loss: 94665.1797 - val_mean_absolute_error: 306.6025
# Epoch 23/100
# 7/7 [==============================] - 0s 10ms/step - loss: 40417.7461 - mean_absolute_error: 173.2768 - val_loss: 79408.6094 - val_mean_absolute_error: 280.6246
# Epoch 24/100
# 7/7 [==============================] - 0s 16ms/step - loss: 32572.2129 - mean_absolute_error: 151.8898 - val_loss: 66891.5234 - val_mean_absolute_error: 257.3498
# Epoch 25/100
# 7/7 [==============================] - 0s 22ms/step - loss: 26157.3359 - mean_absolute_error: 133.3569 - val_loss: 55583.9844 - val_mean_absolute_error: 234.3749
# Epoch 26/100
# 7/7 [==============================] - 0s 19ms/step - loss: 21188.0664 - mean_absolute_error: 119.3741 - val_loss: 46367.5156 - val_mean_absolute_error: 213.8109
# Epoch 27/100
# 7/7 [==============================] - 0s 10ms/step - loss: 17274.4941 - mean_absolute_error: 108.1358 - val_loss: 38690.2109 - val_mean_absolute_error: 195.0706
# Epoch 28/100
# 7/7 [==============================] - 0s 10ms/step - loss: 14476.9287 - mean_absolute_error: 100.8131 - val_loss: 31860.6211 - val_mean_absolute_error: 176.6620
# Epoch 29/100
# 7/7 [==============================] - 0s 9ms/step - loss: 12304.6875 - mean_absolute_error: 96.2724 - val_loss: 26584.1348 - val_mean_absolute_error: 161.0374
# Epoch 30/100
# 7/7 [==============================] - 0s 9ms/step - loss: 10837.1113 - mean_absolute_error: 93.5369 - val_loss: 22764.0586 - val_mean_absolute_error: 148.7720
# Epoch 31/100
# 7/7 [==============================] - 0s 9ms/step - loss: 9750.7275 - mean_absolute_error: 90.5462 - val_loss: 19396.4707 - val_mean_absolute_error: 137.0226
# Epoch 32/100
# 7/7 [==============================] - 0s 10ms/step - loss: 8978.6240 - mean_absolute_error: 88.0122 - val_loss: 17088.6016 - val_mean_absolute_error: 128.3053
# Epoch 33/100
# 7/7 [==============================] - 0s 10ms/step - loss: 8208.7158 - mean_absolute_error: 84.3722 - val_loss: 15925.0381 - val_mean_absolute_error: 123.8912
# Epoch 34/100
# 7/7 [==============================] - 0s 10ms/step - loss: 6961.4370 - mean_absolute_error: 77.7191 - val_loss: 14932.9951 - val_mean_absolute_error: 120.2036
# Epoch 35/100
# 7/7 [==============================] - 0s 9ms/step - loss: 5312.6396 - mean_absolute_error: 66.3044 - val_loss: 12072.2637 - val_mean_absolute_error: 107.3203
# Epoch 36/100
# 7/7 [==============================] - 0s 9ms/step - loss: 4355.7573 - mean_absolute_error: 58.8621 - val_loss: 10257.4307 - val_mean_absolute_error: 98.4692
# Epoch 37/100
# 7/7 [==============================] - 0s 9ms/step - loss: 3414.4451 - mean_absolute_error: 52.0256 - val_loss: 9410.4902 - val_mean_absolute_error: 94.7387
# Epoch 38/100
# 7/7 [==============================] - 0s 11ms/step - loss: 2570.7222 - mean_absolute_error: 44.2009 - val_loss: 7812.6738 - val_mean_absolute_error: 85.6147
# Epoch 39/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1859.2256 - mean_absolute_error: 34.7859 - val_loss: 5680.8853 - val_mean_absolute_error: 71.7149
# Epoch 40/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1273.6465 - mean_absolute_error: 28.0415 - val_loss: 4586.1548 - val_mean_absolute_error: 63.9422
# Epoch 41/100
# 7/7 [==============================] - 0s 8ms/step - loss: 869.2241 - mean_absolute_error: 21.9316 - val_loss: 3749.7041 - val_mean_absolute_error: 57.2543
# Epoch 42/100
# 7/7 [==============================] - 0s 9ms/step - loss: 671.5306 - mean_absolute_error: 19.1767 - val_loss: 2957.8381 - val_mean_absolute_error: 50.0795
# Epoch 43/100
# 7/7 [==============================] - 0s 9ms/step - loss: 511.2878 - mean_absolute_error: 16.1235 - val_loss: 2304.8862 - val_mean_absolute_error: 43.7583
# Epoch 44/100
# 7/7 [==============================] - 0s 11ms/step - loss: 393.0858 - mean_absolute_error: 13.9842 - val_loss: 1933.3188 - val_mean_absolute_error: 39.9106
# Epoch 45/100
# 7/7 [==============================] - 0s 11ms/step - loss: 329.8765 - mean_absolute_error: 13.1417 - val_loss: 1666.8527 - val_mean_absolute_error: 36.9130
# Epoch 46/100
# 7/7 [==============================] - 0s 22ms/step - loss: 284.8394 - mean_absolute_error: 12.0081 - val_loss: 1449.4130 - val_mean_absolute_error: 34.2619
# Epoch 47/100
# 7/7 [==============================] - 0s 14ms/step - loss: 256.8152 - mean_absolute_error: 11.8756 - val_loss: 1391.9172 - val_mean_absolute_error: 33.6506
# Epoch 48/100
# 7/7 [==============================] - 0s 15ms/step - loss: 244.5555 - mean_absolute_error: 11.0886 - val_loss: 1173.9863 - val_mean_absolute_error: 30.5922
# Epoch 49/100
# 7/7 [==============================] - 0s 11ms/step - loss: 221.7273 - mean_absolute_error: 10.6699 - val_loss: 1082.4983 - val_mean_absolute_error: 29.2756
# Epoch 50/100
# 7/7 [==============================] - 0s 11ms/step - loss: 211.5739 - mean_absolute_error: 10.4860 - val_loss: 1030.9275 - val_mean_absolute_error: 28.6612
# Epoch 51/100
# 7/7 [==============================] - 0s 13ms/step - loss: 200.4996 - mean_absolute_error: 10.1678 - val_loss: 912.5807 - val_mean_absolute_error: 26.6363
# Epoch 52/100
# 7/7 [==============================] - 0s 11ms/step - loss: 194.5927 - mean_absolute_error: 10.0776 - val_loss: 933.5169 - val_mean_absolute_error: 27.2374
# Epoch 53/100
# 7/7 [==============================] - 0s 10ms/step - loss: 182.4945 - mean_absolute_error: 9.6641 - val_loss: 828.3171 - val_mean_absolute_error: 25.4109
# Epoch 54/100
# 7/7 [==============================] - 0s 10ms/step - loss: 176.7084 - mean_absolute_error: 9.4423 - val_loss: 763.1552 - val_mean_absolute_error: 24.1887
# Epoch 55/100
# 7/7 [==============================] - 0s 11ms/step - loss: 174.0200 - mean_absolute_error: 9.3838 - val_loss: 705.2444 - val_mean_absolute_error: 23.0727
# Epoch 56/100
# 7/7 [==============================] - 0s 11ms/step - loss: 176.8262 - mean_absolute_error: 9.5206 - val_loss: 693.8526 - val_mean_absolute_error: 23.0541
# Epoch 57/100
# 7/7 [==============================] - 0s 9ms/step - loss: 184.1079 - mean_absolute_error: 10.3046 - val_loss: 628.3511 - val_mean_absolute_error: 21.5899
# Epoch 58/100
# 7/7 [==============================] - 0s 9ms/step - loss: 201.7307 - mean_absolute_error: 10.2187 - val_loss: 702.5419 - val_mean_absolute_error: 23.3937
# Epoch 59/100
# 7/7 [==============================] - 0s 12ms/step - loss: 181.6292 - mean_absolute_error: 9.8765 - val_loss: 672.4873 - val_mean_absolute_error: 22.8193
# Epoch 60/100
# 7/7 [==============================] - 0s 9ms/step - loss: 165.9016 - mean_absolute_error: 9.1351 - val_loss: 608.5321 - val_mean_absolute_error: 21.4707
# Epoch 61/100
# 7/7 [==============================] - 0s 14ms/step - loss: 173.5645 - mean_absolute_error: 9.6351 - val_loss: 528.4454 - val_mean_absolute_error: 19.5226
# Epoch 62/100
# 7/7 [==============================] - 0s 22ms/step - loss: 158.1512 - mean_absolute_error: 9.0462 - val_loss: 678.6844 - val_mean_absolute_error: 23.2821
# Epoch 63/100
# 7/7 [==============================] - 0s 19ms/step - loss: 173.6740 - mean_absolute_error: 9.4531 - val_loss: 651.3251 - val_mean_absolute_error: 22.8551
# Epoch 64/100
# 7/7 [==============================] - 0s 19ms/step - loss: 151.0527 - mean_absolute_error: 8.9203 - val_loss: 611.2860 - val_mean_absolute_error: 21.9450
# Epoch 65/100
# 7/7 [==============================] - 0s 19ms/step - loss: 155.2428 - mean_absolute_error: 8.7903 - val_loss: 585.7919 - val_mean_absolute_error: 21.4288
# Epoch 66/100
# 7/7 [==============================] - 0s 22ms/step - loss: 160.4104 - mean_absolute_error: 9.3722 - val_loss: 509.1353 - val_mean_absolute_error: 19.4892
# Epoch 67/100
# 7/7 [==============================] - 0s 21ms/step - loss: 167.2181 - mean_absolute_error: 9.5460 - val_loss: 435.0502 - val_mean_absolute_error: 17.5865
# Epoch 68/100
# 7/7 [==============================] - 0s 17ms/step - loss: 164.5277 - mean_absolute_error: 9.2416 - val_loss: 400.1381 - val_mean_absolute_error: 16.7596
# Epoch 69/100
# 7/7 [==============================] - 0s 17ms/step - loss: 213.2289 - mean_absolute_error: 11.1442 - val_loss: 493.5569 - val_mean_absolute_error: 19.3180
# Epoch 70/100
# 7/7 [==============================] - 0s 24ms/step - loss: 196.6980 - mean_absolute_error: 10.9548 - val_loss: 791.4250 - val_mean_absolute_error: 25.9126
# Epoch 71/100
# 7/7 [==============================] - 0s 21ms/step - loss: 180.6933 - mean_absolute_error: 10.4475 - val_loss: 543.1858 - val_mean_absolute_error: 20.6577
# Epoch 72/100
# 7/7 [==============================] - 0s 21ms/step - loss: 147.2775 - mean_absolute_error: 8.4919 - val_loss: 412.3617 - val_mean_absolute_error: 17.0912
# Epoch 73/100
# 7/7 [==============================] - 0s 20ms/step - loss: 154.8507 - mean_absolute_error: 8.6475 - val_loss: 382.5807 - val_mean_absolute_error: 16.3412
# Epoch 74/100
# 7/7 [==============================] - 0s 13ms/step - loss: 156.1664 - mean_absolute_error: 9.4140 - val_loss: 491.2267 - val_mean_absolute_error: 19.5105
# Epoch 75/100
# 7/7 [==============================] - 0s 9ms/step - loss: 138.5242 - mean_absolute_error: 8.6646 - val_loss: 401.3692 - val_mean_absolute_error: 17.1401
# Epoch 76/100
# 7/7 [==============================] - 0s 9ms/step - loss: 148.4282 - mean_absolute_error: 8.7959 - val_loss: 514.9764 - val_mean_absolute_error: 20.3121
# Epoch 77/100
# 7/7 [==============================] - 0s 9ms/step - loss: 158.1886 - mean_absolute_error: 9.4738 - val_loss: 547.2227 - val_mean_absolute_error: 21.1473
# Epoch 78/100
# 7/7 [==============================] - 0s 10ms/step - loss: 155.4893 - mean_absolute_error: 8.9848 - val_loss: 616.6365 - val_mean_absolute_error: 22.8078
# Epoch 79/100
# 7/7 [==============================] - 0s 9ms/step - loss: 231.9154 - mean_absolute_error: 11.5632 - val_loss: 367.9528 - val_mean_absolute_error: 16.1892
# Epoch 80/100
# 7/7 [==============================] - 0s 10ms/step - loss: 167.4025 - mean_absolute_error: 9.2618 - val_loss: 387.4193 - val_mean_absolute_error: 16.6394
# Epoch 81/100
# 7/7 [==============================] - 0s 9ms/step - loss: 150.7910 - mean_absolute_error: 8.8747 - val_loss: 398.4099 - val_mean_absolute_error: 17.0629
# Epoch 82/100
# 7/7 [==============================] - 0s 10ms/step - loss: 155.2248 - mean_absolute_error: 9.1595 - val_loss: 565.4596 - val_mean_absolute_error: 21.4738
# Epoch 83/100
# 7/7 [==============================] - 0s 10ms/step - loss: 156.9956 - mean_absolute_error: 8.9297 - val_loss: 506.6483 - val_mean_absolute_error: 20.0438
# Epoch 84/100
# 7/7 [==============================] - 0s 9ms/step - loss: 137.4700 - mean_absolute_error: 8.2843 - val_loss: 505.4252 - val_mean_absolute_error: 20.1558
# Epoch 85/100
# 7/7 [==============================] - 0s 10ms/step - loss: 142.0858 - mean_absolute_error: 8.4201 - val_loss: 350.4160 - val_mean_absolute_error: 16.0418
# Epoch 86/100
# 7/7 [==============================] - 0s 9ms/step - loss: 127.4454 - mean_absolute_error: 7.9711 - val_loss: 497.1531 - val_mean_absolute_error: 20.1429
# Epoch 87/100
# 7/7 [==============================] - 0s 9ms/step - loss: 141.4310 - mean_absolute_error: 8.4603 - val_loss: 487.9515 - val_mean_absolute_error: 19.9512
# Epoch 88/100
# 7/7 [==============================] - 0s 9ms/step - loss: 141.8755 - mean_absolute_error: 8.7667 - val_loss: 357.3116 - val_mean_absolute_error: 16.5050
# Epoch 89/100
# 7/7 [==============================] - 0s 9ms/step - loss: 134.7695 - mean_absolute_error: 8.4065 - val_loss: 320.4522 - val_mean_absolute_error: 15.4022
# Epoch 90/100
# 7/7 [==============================] - 0s 10ms/step - loss: 135.1761 - mean_absolute_error: 8.6511 - val_loss: 317.7640 - val_mean_absolute_error: 15.3505
# Epoch 91/100
# 7/7 [==============================] - 0s 10ms/step - loss: 133.1255 - mean_absolute_error: 8.2843 - val_loss: 278.3977 - val_mean_absolute_error: 14.1093
# Epoch 92/100
# 7/7 [==============================] - 0s 9ms/step - loss: 146.2432 - mean_absolute_error: 8.8147 - val_loss: 244.7280 - val_mean_absolute_error: 12.7375
# Epoch 93/100
# 7/7 [==============================] - 0s 11ms/step - loss: 151.6210 - mean_absolute_error: 9.3078 - val_loss: 247.0417 - val_mean_absolute_error: 12.8522
# Epoch 94/100
# 7/7 [==============================] - 0s 11ms/step - loss: 134.7722 - mean_absolute_error: 8.0835 - val_loss: 319.3572 - val_mean_absolute_error: 15.4446
# Epoch 95/100
# 7/7 [==============================] - 0s 11ms/step - loss: 143.2862 - mean_absolute_error: 8.7907 - val_loss: 242.4152 - val_mean_absolute_error: 12.6735
# Epoch 96/100
# 7/7 [==============================] - 0s 12ms/step - loss: 148.1657 - mean_absolute_error: 8.6687 - val_loss: 283.4478 - val_mean_absolute_error: 14.3348
# Epoch 97/100
# 7/7 [==============================] - 0s 13ms/step - loss: 170.9564 - mean_absolute_error: 9.5429 - val_loss: 434.0651 - val_mean_absolute_error: 18.6923
# Epoch 98/100
# 7/7 [==============================] - 0s 11ms/step - loss: 143.0816 - mean_absolute_error: 8.7968 - val_loss: 460.8854 - val_mean_absolute_error: 19.4132
# Epoch 99/100
# 7/7 [==============================] - 0s 9ms/step - loss: 175.8371 - mean_absolute_error: 9.6661 - val_loss: 650.4685 - val_mean_absolute_error: 23.9800
# Epoch 100/100
# 7/7 [==============================] - 0s 10ms/step - loss: 171.0753 - mean_absolute_error: 10.1356 - val_loss: 342.5201 - val_mean_absolute_error: 16.1453

# %%
# Save the model:
#from tensorflow.keras.models import load_model
#model.save("my_model")

# %%
from tensorflow.keras.models import load_model
import tensorflow as tf

# Load the model back
model = load_model("my_model")

# Suppress the deprecation warning
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
# Out:
# WARNING:tensorflow:From C:\Users\mball3\AppData\Local\anaconda3\Lib\site-packages\keras\src\saving\legacy\saved_model\load.py:107: The name tf.gfile.Exists is deprecated. Please use tf.io.gfile.exists instead.
#
# WARNING:tensorflow:From C:\Users\mball3\AppData\Local\Temp\ipykernel_28352\1675761982.py:8: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.

# %%
# You can plot the models predictions against the observations
# For the training data
train_predictions = model.predict(X_train).flatten()

mae = sum(abs(train_predictions-Y_train))/len(train_predictions)

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, Y_train)
plt.legend(['Training_Predictions','Training_Observations'])
plt.text(0.02, 0.79, f'MAE: {mae:.2f}', transform=plt.gca().transAxes, color='blue', fontsize=12)


plt.xticks(rotation=45)
# Out:
# 7/7 [==============================] - 1s 2ms/step
# (array([19358., 19389., 19417., 19448., 19478., 19509., 19539., 19570.,
#         19601., 19631., 19662.]),
#  [Text(19358.0, 0, '2023-01'),
#   Text(19389.0, 0, '2023-02'),
#   Text(19417.0, 0, '2023-03'),
#   Text(19448.0, 0, '2023-04'),
#   Text(19478.0, 0, '2023-05'),
#   Text(19509.0, 0, '2023-06'),
#   Text(19539.0, 0, '2023-07'),
#   Text(19570.0, 0, '2023-08'),
#   Text(19601.0, 0, '2023-09'),
#   Text(19631.0, 0, '2023-10'),
#   Text(19662.0, 0, '2023-11')])

# %% [markdown]
# - The trained model closely fits the actual data, as expected
# - The MAE is 7.76, meaning the average difference between the actual and predicted stock price is $7.76
# - This seems very reasonable

# %% [markdown]
# *Now to look at the validation dataset*

# %%
# For the validation data
val_predictions = model.predict(X_val).flatten()

mae = sum(abs(val_predictions-Y_val))/len(val_predictions)

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, Y_val)
plt.legend(['Validation_Predictions','Validation_Observations'])
plt.text(0.02, 0.79, f'MAE: {mae:.2f}', transform=plt.gca().transAxes, color='blue', fontsize=12)
plt.xticks(rotation=45)
# Out:
# 1/1 [==============================] - 0s 26ms/step
# (array([19659., 19662., 19666., 19670., 19674., 19678., 19682., 19686.,
#         19690., 19692., 19696.]),
#  [Text(19659.0, 0, '2023-10-29'),
#   Text(19662.0, 0, '2023-11-01'),
#   Text(19666.0, 0, '2023-11-05'),
#   Text(19670.0, 0, '2023-11-09'),
#   Text(19674.0, 0, '2023-11-13'),
#   Text(19678.0, 0, '2023-11-17'),
#   Text(19682.0, 0, '2023-11-21'),
#   Text(19686.0, 0, '2023-11-25'),
#   Text(19690.0, 0, '2023-11-29'),
#   Text(19692.0, 0, '2023-12-01'),
#   Text(19696.0, 0, '2023-12-05')])

# %% [markdown]
# - The performance of the model isn't bad
# - The model is able to accurately predict the shape of this curve fairly well
# - The MAE has doubled now, but it still seems to be reasonable

# %%
# For the test data
test_predictions = model.predict(X_test).flatten()

mae = sum(abs(test_predictions-Y_test))/len(test_predictions)

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, Y_test)
plt.legend(['Test_Predictions','Test_Observations'])
plt.text(0.02, 0.79, f'MAE: {mae:.2f}', transform=plt.gca().transAxes, color='blue', fontsize=12)
plt.xticks(rotation=45)
# Out:
# 1/1 [==============================] - 0s 26ms/step
# (array([19696., 19700., 19704., 19708., 19712., 19716., 19720., 19723.,
#         19727., 19731., 19735.]),
#  [Text(19696.0, 0, '2023-12-05'),
#   Text(19700.0, 0, '2023-12-09'),
#   Text(19704.0, 0, '2023-12-13'),
#   Text(19708.0, 0, '2023-12-17'),
#   Text(19712.0, 0, '2023-12-21'),
#   Text(19716.0, 0, '2023-12-25'),
#   Text(19720.0, 0, '2023-12-29'),
#   Text(19723.0, 0, '2024-01-01'),
#   Text(19727.0, 0, '2024-01-05'),
#   Text(19731.0, 0, '2024-01-09'),
#   Text(19735.0, 0, '2024-01-13')])

# %% [markdown]
# - Again the MAE has increased, but only being out by $27.31 on average is good!

# %%
# Lets plot everything together 
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, Y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, Y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, Y_test)
plt.legend(['Training_Predictions','Training_Observations', 
            'Validation_Predictions','Validation_Observations',
            'Test_Predictions','Test_Observations'])

# %% [markdown]
# **Making predictions!**
# - here I am using the predict function of the lstm model to predict stock prices based on the training data alone
# - this is taking the last entry of the training data - the three days of prices at this date (because the window is 3)
# - then based on these prices it's predicting the next price
# - the window of three prices is updated with this newly predicted price
# - this process repeats itself for the whole period

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])
last_window = deepcopy(X_train[-1])

for target_date in recursive_dates:
    next_prediction = model.predict(np.array([last_window])).flatten()
    recursive_predictions.append(next_prediction)
    last_window = np.vstack([last_window[1:], [next_prediction]])
# Out:
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step

# %% [markdown]
# - I now compare the predicted prices vs the validation and test data

# %%
# Lets plot everything together 
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, Y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, Y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, Y_test)
plt.plot(recursive_dates, recursive_predictions)

#MAE
Y_val_test = np.concatenate([Y_val, Y_test])

mae_store = []

for obs, pred in zip(Y_val_test, recursive_predictions):
    value = abs(obs - pred)
    mae_store.append(value)
    
mae = sum(mae_store)/len(mae_store)


plt.legend(['Training_Predictions','Training_Observations', 
            'Validation_Predictions','Validation_Observations',
            'Test_Predictions','Test_Observations', 
           'Recursive_Predictions'])

plt.text(0.02, 0.79, f'MAE: {mae[0]:.2f}', transform=plt.gca().transAxes, color='blue', fontsize=12)
# Out:
# Text(0.02, 0.79, 'MAE: 47.39')

# %%
mae_of_price = (mae/Y_val_test.mean())*100
mae_of_price
# Out:
# array([9.842799], dtype=float32)

# %% [markdown]
# - the Mean Absolute Error when comparing the models predictions and the evaluation & test data is worse still
# - on average, predictions are wrong by $47.39, this is the mae
# - but is this is large or small value? well it is 9.8% of the stocks actual price over the eval/test period
# - so there is a significant difference, but realistically this is not dramatically wrong
# - the model is able to predict a fairly reasonable price
# - here we can see that the model seems to understand that the stock price is in a dip and that it will soon increase
# - over a longer period is assumes this price will stabilise, which is unlikely

# %% [markdown]
# **I am going to increase the size of the training data, by including eval data in training data and observe performance**

# %%
# PLOT
q_90 = int(len(dates) *.9)

#Train
dates_train2, X_train2, Y_train2 = dates[:q_90], X[:q_90], Y[:q_90]

#Test
dates_test2, X_test2, Y_test2 = dates[q_90:], X[q_90:], Y[q_90:]

# Plot
plt.plot(dates_train2, Y_train2)
plt.plot(dates_test2, Y_test2)
plt.legend(['Train', 'Test'])
plt.ylabel('Close Price ($)')
# Out:
# Text(0, 0.5, 'Close Price ($)')

# %%
# BUILD THE MODEL

model2 = Sequential([layers.Input((3,1)), # there are three layers to out input data, because the window has three layers
                   layers.LSTM(64), # number of nuerons in the neural network - this is a good level to prevent overfitting 
                   layers.Dense(32, activation='relu'), # this creates another layer in the NN
                   layers.Dense(32, activation='relu'), # do another
                   layers.Dense(1) # final layer
                   ])

model2.compile(loss='mse', # loss means we are trying to minimise the mean squared error
              optimizer=Adam(learning_rate=0.001), # try this learning rate
              metrics = ['mean_absolute_error'] # this allows us to see on average how off the model is
                                                # it makes more sense to interpret this, even if minimising the mean squared error
             )


model2.fit(X_train2, Y_train2, validation_data=(X_test2, Y_test2), epochs=100 ) # runs for 100 times on the training data

train_predictions2 = model2.predict(X_train2).flatten()

# PREDICT
recursive_predictions2 = []
recursive_dates2 = dates_test2
last_window2 = deepcopy(X_train2[-1])

for target_date2 in recursive_dates2:
    next_prediction2 = model2.predict(np.array([last_window2])).flatten()
    recursive_predictions2.append(next_prediction2)
    last_window2 = np.vstack([last_window2[1:], [next_prediction2]])
# Out:
# Epoch 1/100
# 8/8 [==============================] - 4s 126ms/step - loss: 140266.6719 - mean_absolute_error: 359.8035 - val_loss: 244353.0000 - val_mean_absolute_error: 493.7201
# Epoch 2/100
# 8/8 [==============================] - 0s 9ms/step - loss: 139922.0781 - mean_absolute_error: 359.3220 - val_loss: 244005.3125 - val_mean_absolute_error: 493.3678
# Epoch 3/100
# 8/8 [==============================] - 0s 8ms/step - loss: 139632.5781 - mean_absolute_error: 358.9083 - val_loss: 243498.9062 - val_mean_absolute_error: 492.8542
# Epoch 4/100
# 8/8 [==============================] - 0s 9ms/step - loss: 139151.0000 - mean_absolute_error: 358.2478 - val_loss: 242688.9688 - val_mean_absolute_error: 492.0321
# Epoch 5/100
# 8/8 [==============================] - 0s 9ms/step - loss: 138638.9531 - mean_absolute_error: 357.5265 - val_loss: 242045.0000 - val_mean_absolute_error: 491.3772
# Epoch 6/100
# 8/8 [==============================] - 0s 9ms/step - loss: 138118.8125 - mean_absolute_error: 356.8037 - val_loss: 241231.6406 - val_mean_absolute_error: 490.5488
# Epoch 7/100
# 8/8 [==============================] - 0s 9ms/step - loss: 137470.7344 - mean_absolute_error: 355.8781 - val_loss: 240157.4219 - val_mean_absolute_error: 489.4525
# Epoch 8/100
# 8/8 [==============================] - 0s 9ms/step - loss: 136585.2656 - mean_absolute_error: 354.6272 - val_loss: 238816.9844 - val_mean_absolute_error: 488.0813
# Epoch 9/100
# 8/8 [==============================] - 0s 12ms/step - loss: 135373.0156 - mean_absolute_error: 352.9220 - val_loss: 236589.0312 - val_mean_absolute_error: 485.7937
# Epoch 10/100
# 8/8 [==============================] - 0s 16ms/step - loss: 133656.8125 - mean_absolute_error: 350.4667 - val_loss: 233897.2656 - val_mean_absolute_error: 483.0149
# Epoch 11/100
# 8/8 [==============================] - 0s 11ms/step - loss: 131440.6406 - mean_absolute_error: 347.2569 - val_loss: 230352.2656 - val_mean_absolute_error: 479.3309
# Epoch 12/100
# 8/8 [==============================] - 0s 10ms/step - loss: 128135.0078 - mean_absolute_error: 342.4262 - val_loss: 224446.6875 - val_mean_absolute_error: 473.1303
# Epoch 13/100
# 8/8 [==============================] - 0s 10ms/step - loss: 123701.6875 - mean_absolute_error: 335.9366 - val_loss: 217654.9219 - val_mean_absolute_error: 465.8981
# Epoch 14/100
# 8/8 [==============================] - 0s 11ms/step - loss: 118703.9922 - mean_absolute_error: 328.5085 - val_loss: 209976.4844 - val_mean_absolute_error: 457.5832
# Epoch 15/100
# 8/8 [==============================] - 0s 10ms/step - loss: 112997.0859 - mean_absolute_error: 319.7038 - val_loss: 201435.7188 - val_mean_absolute_error: 448.1541
# Epoch 16/100
# 8/8 [==============================] - 0s 10ms/step - loss: 106569.9531 - mean_absolute_error: 309.4832 - val_loss: 191089.7500 - val_mean_absolute_error: 436.4588
# Epoch 17/100
# 8/8 [==============================] - 0s 11ms/step - loss: 99190.5234 - mean_absolute_error: 296.9720 - val_loss: 179355.5312 - val_mean_absolute_error: 422.7973
# Epoch 18/100
# 8/8 [==============================] - 0s 9ms/step - loss: 90013.7031 - mean_absolute_error: 281.1008 - val_loss: 164934.2344 - val_mean_absolute_error: 405.3885
# Epoch 19/100
# 8/8 [==============================] - 0s 8ms/step - loss: 80563.8281 - mean_absolute_error: 264.2331 - val_loss: 150970.8438 - val_mean_absolute_error: 387.7842
# Epoch 20/100
# 8/8 [==============================] - 0s 8ms/step - loss: 70915.5078 - mean_absolute_error: 245.2723 - val_loss: 135320.0469 - val_mean_absolute_error: 367.0504
# Epoch 21/100
# 8/8 [==============================] - 0s 9ms/step - loss: 60846.6406 - mean_absolute_error: 223.2489 - val_loss: 118410.3438 - val_mean_absolute_error: 343.2420
# Epoch 22/100
# 8/8 [==============================] - 0s 10ms/step - loss: 50114.3477 - mean_absolute_error: 198.0613 - val_loss: 100389.5859 - val_mean_absolute_error: 315.8888
# Epoch 23/100
# 8/8 [==============================] - 0s 10ms/step - loss: 38839.6484 - mean_absolute_error: 169.4985 - val_loss: 80504.3984 - val_mean_absolute_error: 282.6835
# Epoch 24/100
# 8/8 [==============================] - 0s 9ms/step - loss: 29634.0801 - mean_absolute_error: 144.7582 - val_loss: 64245.6055 - val_mean_absolute_error: 252.2931
# Epoch 25/100
# 8/8 [==============================] - 0s 9ms/step - loss: 22356.0039 - mean_absolute_error: 125.6700 - val_loss: 51305.1211 - val_mean_absolute_error: 225.1925
# Epoch 26/100
# 8/8 [==============================] - 0s 9ms/step - loss: 17584.1680 - mean_absolute_error: 113.4801 - val_loss: 40690.9141 - val_mean_absolute_error: 200.2441
# Epoch 27/100
# 8/8 [==============================] - 0s 9ms/step - loss: 14002.0117 - mean_absolute_error: 105.3861 - val_loss: 32863.6211 - val_mean_absolute_error: 179.6472
# Epoch 28/100
# 8/8 [==============================] - 0s 11ms/step - loss: 12019.5898 - mean_absolute_error: 101.5211 - val_loss: 26726.6055 - val_mean_absolute_error: 161.6732
# Epoch 29/100
# 8/8 [==============================] - 0s 10ms/step - loss: 10699.3682 - mean_absolute_error: 97.1362 - val_loss: 22309.3633 - val_mean_absolute_error: 147.3791
# Epoch 30/100
# 8/8 [==============================] - 0s 10ms/step - loss: 10077.0342 - mean_absolute_error: 94.6148 - val_loss: 19441.9180 - val_mean_absolute_error: 137.3462
# Epoch 31/100
# 8/8 [==============================] - 0s 10ms/step - loss: 9381.6650 - mean_absolute_error: 91.1974 - val_loss: 21744.4258 - val_mean_absolute_error: 145.5743
# Epoch 32/100
# 8/8 [==============================] - 0s 10ms/step - loss: 8204.9824 - mean_absolute_error: 84.5252 - val_loss: 16905.9082 - val_mean_absolute_error: 127.9000
# Epoch 33/100
# 8/8 [==============================] - 0s 8ms/step - loss: 6414.1602 - mean_absolute_error: 75.6579 - val_loss: 15619.5459 - val_mean_absolute_error: 122.7903
# Epoch 34/100
# 8/8 [==============================] - 0s 9ms/step - loss: 5065.3604 - mean_absolute_error: 66.4933 - val_loss: 13223.8701 - val_mean_absolute_error: 112.6950
# Epoch 35/100
# 8/8 [==============================] - 0s 8ms/step - loss: 3521.6799 - mean_absolute_error: 54.4253 - val_loss: 10396.6152 - val_mean_absolute_error: 99.2905
# Epoch 36/100
# 8/8 [==============================] - 0s 9ms/step - loss: 2337.2693 - mean_absolute_error: 42.4444 - val_loss: 8620.0674 - val_mean_absolute_error: 89.9615
# Epoch 37/100
# 8/8 [==============================] - 0s 11ms/step - loss: 1564.3292 - mean_absolute_error: 33.3057 - val_loss: 6725.2178 - val_mean_absolute_error: 78.6902
# Epoch 38/100
# 8/8 [==============================] - 0s 13ms/step - loss: 986.9787 - mean_absolute_error: 24.3371 - val_loss: 5184.6641 - val_mean_absolute_error: 68.1205
# Epoch 39/100
# 8/8 [==============================] - 0s 14ms/step - loss: 660.8021 - mean_absolute_error: 18.8162 - val_loss: 4194.4238 - val_mean_absolute_error: 60.4580
# Epoch 40/100
# 8/8 [==============================] - 0s 18ms/step - loss: 492.8027 - mean_absolute_error: 16.2838 - val_loss: 3482.3215 - val_mean_absolute_error: 54.3316
# Epoch 41/100
# 8/8 [==============================] - 0s 16ms/step - loss: 398.3867 - mean_absolute_error: 14.4513 - val_loss: 3047.7031 - val_mean_absolute_error: 50.3212
# Epoch 42/100
# 8/8 [==============================] - 0s 16ms/step - loss: 352.8864 - mean_absolute_error: 13.5603 - val_loss: 2574.1184 - val_mean_absolute_error: 45.2061
# Epoch 43/100
# 8/8 [==============================] - 0s 8ms/step - loss: 316.3630 - mean_absolute_error: 13.2616 - val_loss: 2460.0081 - val_mean_absolute_error: 44.3096
# Epoch 44/100
# 8/8 [==============================] - 0s 8ms/step - loss: 278.8718 - mean_absolute_error: 12.3756 - val_loss: 2261.1821 - val_mean_absolute_error: 42.1159
# Epoch 45/100
# 8/8 [==============================] - 0s 10ms/step - loss: 247.9648 - mean_absolute_error: 11.4164 - val_loss: 2009.0399 - val_mean_absolute_error: 38.8522
# Epoch 46/100
# 8/8 [==============================] - 0s 11ms/step - loss: 249.3867 - mean_absolute_error: 11.5360 - val_loss: 1860.7786 - val_mean_absolute_error: 36.9750
# Epoch 47/100
# 8/8 [==============================] - 0s 10ms/step - loss: 237.4854 - mean_absolute_error: 11.6094 - val_loss: 1686.2942 - val_mean_absolute_error: 34.4183
# Epoch 48/100
# 8/8 [==============================] - 0s 9ms/step - loss: 238.5214 - mean_absolute_error: 11.5055 - val_loss: 1755.9698 - val_mean_absolute_error: 35.9537
# Epoch 49/100
# 8/8 [==============================] - 0s 8ms/step - loss: 251.1030 - mean_absolute_error: 11.9061 - val_loss: 1553.5039 - val_mean_absolute_error: 32.8255
# Epoch 50/100
# 8/8 [==============================] - 0s 20ms/step - loss: 260.0065 - mean_absolute_error: 11.9157 - val_loss: 1649.1655 - val_mean_absolute_error: 34.7135
# Epoch 51/100
# 8/8 [==============================] - 0s 21ms/step - loss: 206.0936 - mean_absolute_error: 10.8767 - val_loss: 1725.2000 - val_mean_absolute_error: 36.2964
# Epoch 52/100
# 8/8 [==============================] - 0s 17ms/step - loss: 194.3564 - mean_absolute_error: 10.1161 - val_loss: 1675.1244 - val_mean_absolute_error: 35.6755
# Epoch 53/100
# 8/8 [==============================] - 0s 20ms/step - loss: 184.4754 - mean_absolute_error: 9.9122 - val_loss: 1448.1584 - val_mean_absolute_error: 31.9460
# Epoch 54/100
# 8/8 [==============================] - 0s 11ms/step - loss: 178.0581 - mean_absolute_error: 9.6963 - val_loss: 1337.3589 - val_mean_absolute_error: 30.2245
# Epoch 55/100
# 8/8 [==============================] - 0s 9ms/step - loss: 182.8808 - mean_absolute_error: 10.0762 - val_loss: 1468.1639 - val_mean_absolute_error: 32.8629
# Epoch 56/100
# 8/8 [==============================] - 0s 10ms/step - loss: 176.2714 - mean_absolute_error: 9.5566 - val_loss: 1378.0002 - val_mean_absolute_error: 31.4308
# Epoch 57/100
# 8/8 [==============================] - 0s 10ms/step - loss: 162.1534 - mean_absolute_error: 9.2600 - val_loss: 1123.3357 - val_mean_absolute_error: 26.6616
# Epoch 58/100
# 8/8 [==============================] - 0s 10ms/step - loss: 169.1731 - mean_absolute_error: 9.7777 - val_loss: 1050.2863 - val_mean_absolute_error: 25.1825
# Epoch 59/100
# 8/8 [==============================] - 0s 11ms/step - loss: 204.6732 - mean_absolute_error: 10.7063 - val_loss: 1207.3186 - val_mean_absolute_error: 28.6709
# Epoch 60/100
# 8/8 [==============================] - 0s 12ms/step - loss: 170.8261 - mean_absolute_error: 9.6661 - val_loss: 1076.7101 - val_mean_absolute_error: 26.2463
# Epoch 61/100
# 8/8 [==============================] - 0s 8ms/step - loss: 176.1978 - mean_absolute_error: 9.6413 - val_loss: 973.6764 - val_mean_absolute_error: 24.1335
# Epoch 62/100
# 8/8 [==============================] - 0s 20ms/step - loss: 186.7027 - mean_absolute_error: 10.0666 - val_loss: 1073.1116 - val_mean_absolute_error: 26.5041
# Epoch 63/100
# 8/8 [==============================] - 0s 16ms/step - loss: 148.5897 - mean_absolute_error: 8.8642 - val_loss: 1015.6445 - val_mean_absolute_error: 25.3623
# Epoch 64/100
# 8/8 [==============================] - 0s 10ms/step - loss: 145.1380 - mean_absolute_error: 8.6863 - val_loss: 1253.7179 - val_mean_absolute_error: 30.3836
# Epoch 65/100
# 8/8 [==============================] - 0s 9ms/step - loss: 167.6645 - mean_absolute_error: 9.3089 - val_loss: 1283.5890 - val_mean_absolute_error: 31.0470
# Epoch 66/100
# 8/8 [==============================] - 0s 11ms/step - loss: 183.9064 - mean_absolute_error: 9.9974 - val_loss: 1092.1487 - val_mean_absolute_error: 27.3372
# Epoch 67/100
# 8/8 [==============================] - 0s 11ms/step - loss: 146.6300 - mean_absolute_error: 8.8095 - val_loss: 1090.9799 - val_mean_absolute_error: 27.4077
# Epoch 68/100
# 8/8 [==============================] - 0s 8ms/step - loss: 144.7571 - mean_absolute_error: 8.8446 - val_loss: 1002.8928 - val_mean_absolute_error: 25.7131
# Epoch 69/100
# 8/8 [==============================] - 0s 10ms/step - loss: 143.5847 - mean_absolute_error: 8.7348 - val_loss: 1288.4961 - val_mean_absolute_error: 31.5738
# Epoch 70/100
# 8/8 [==============================] - 0s 24ms/step - loss: 198.7180 - mean_absolute_error: 10.7175 - val_loss: 1124.0464 - val_mean_absolute_error: 28.4464
# Epoch 71/100
# 8/8 [==============================] - 0s 22ms/step - loss: 176.2721 - mean_absolute_error: 9.8612 - val_loss: 1353.1407 - val_mean_absolute_error: 32.7784
# Epoch 72/100
# 8/8 [==============================] - 0s 21ms/step - loss: 225.3887 - mean_absolute_error: 11.4539 - val_loss: 1114.0448 - val_mean_absolute_error: 28.3717
# Epoch 73/100
# 8/8 [==============================] - 0s 14ms/step - loss: 178.2253 - mean_absolute_error: 9.8985 - val_loss: 1186.8221 - val_mean_absolute_error: 29.8472
# Epoch 74/100
# 8/8 [==============================] - 0s 22ms/step - loss: 155.9648 - mean_absolute_error: 9.2706 - val_loss: 1251.6711 - val_mean_absolute_error: 31.1150
# Epoch 75/100
# 8/8 [==============================] - 0s 12ms/step - loss: 227.2675 - mean_absolute_error: 11.3500 - val_loss: 1004.2146 - val_mean_absolute_error: 26.2029
# Epoch 76/100
# 8/8 [==============================] - 0s 9ms/step - loss: 138.4233 - mean_absolute_error: 8.6991 - val_loss: 961.6711 - val_mean_absolute_error: 25.3733
# Epoch 77/100
# 8/8 [==============================] - 0s 9ms/step - loss: 134.2846 - mean_absolute_error: 8.5023 - val_loss: 876.3932 - val_mean_absolute_error: 23.5561
# Epoch 78/100
# 8/8 [==============================] - 0s 9ms/step - loss: 127.3468 - mean_absolute_error: 8.2253 - val_loss: 852.6777 - val_mean_absolute_error: 23.1397
# Epoch 79/100
# 8/8 [==============================] - 0s 11ms/step - loss: 133.1594 - mean_absolute_error: 8.4224 - val_loss: 964.9704 - val_mean_absolute_error: 25.7408
# Epoch 80/100
# 8/8 [==============================] - 0s 12ms/step - loss: 144.4580 - mean_absolute_error: 8.5165 - val_loss: 1092.8611 - val_mean_absolute_error: 28.5627
# Epoch 81/100
# 8/8 [==============================] - 0s 10ms/step - loss: 190.8304 - mean_absolute_error: 10.0399 - val_loss: 1206.7821 - val_mean_absolute_error: 30.7761
# Epoch 82/100
# 8/8 [==============================] - 0s 12ms/step - loss: 184.0055 - mean_absolute_error: 10.4914 - val_loss: 978.7554 - val_mean_absolute_error: 26.2152
# Epoch 83/100
# 8/8 [==============================] - 0s 10ms/step - loss: 137.0985 - mean_absolute_error: 8.8162 - val_loss: 890.2063 - val_mean_absolute_error: 24.2769
# Epoch 84/100
# 8/8 [==============================] - 0s 11ms/step - loss: 144.0555 - mean_absolute_error: 8.8127 - val_loss: 847.6042 - val_mean_absolute_error: 23.3947
# Epoch 85/100
# 8/8 [==============================] - 0s 10ms/step - loss: 129.8964 - mean_absolute_error: 8.4370 - val_loss: 834.0106 - val_mean_absolute_error: 23.1394
# Epoch 86/100
# 8/8 [==============================] - 0s 10ms/step - loss: 123.2746 - mean_absolute_error: 8.1165 - val_loss: 845.0693 - val_mean_absolute_error: 23.4972
# Epoch 87/100
# 8/8 [==============================] - 0s 11ms/step - loss: 143.7824 - mean_absolute_error: 8.8448 - val_loss: 763.1077 - val_mean_absolute_error: 21.5951
# Epoch 88/100
# 8/8 [==============================] - 0s 11ms/step - loss: 162.1000 - mean_absolute_error: 9.4378 - val_loss: 622.2826 - val_mean_absolute_error: 17.8915
# Epoch 89/100
# 8/8 [==============================] - 0s 14ms/step - loss: 215.9264 - mean_absolute_error: 10.9275 - val_loss: 643.0469 - val_mean_absolute_error: 18.5354
# Epoch 90/100
# 8/8 [==============================] - 0s 10ms/step - loss: 210.5285 - mean_absolute_error: 11.6425 - val_loss: 694.1973 - val_mean_absolute_error: 19.9632
# Epoch 91/100
# 8/8 [==============================] - 0s 10ms/step - loss: 158.5483 - mean_absolute_error: 9.0110 - val_loss: 1022.4327 - val_mean_absolute_error: 27.3565
# Epoch 92/100
# 8/8 [==============================] - 0s 10ms/step - loss: 141.7594 - mean_absolute_error: 8.8754 - val_loss: 907.4960 - val_mean_absolute_error: 25.0493
# Epoch 93/100
# 8/8 [==============================] - 0s 11ms/step - loss: 146.1201 - mean_absolute_error: 8.7688 - val_loss: 723.9073 - val_mean_absolute_error: 20.8305
# Epoch 94/100
# 8/8 [==============================] - 0s 9ms/step - loss: 135.1735 - mean_absolute_error: 8.5017 - val_loss: 630.9925 - val_mean_absolute_error: 18.3214
# Epoch 95/100
# 8/8 [==============================] - 0s 9ms/step - loss: 137.7645 - mean_absolute_error: 8.6832 - val_loss: 609.8823 - val_mean_absolute_error: 17.8133
# Epoch 96/100
# 8/8 [==============================] - 0s 10ms/step - loss: 130.2983 - mean_absolute_error: 8.2747 - val_loss: 598.7982 - val_mean_absolute_error: 17.6646
# Epoch 97/100
# 8/8 [==============================] - 0s 10ms/step - loss: 131.0711 - mean_absolute_error: 8.2320 - val_loss: 592.4180 - val_mean_absolute_error: 17.6214
# Epoch 98/100
# 8/8 [==============================] - 0s 11ms/step - loss: 133.8071 - mean_absolute_error: 8.3155 - val_loss: 548.4625 - val_mean_absolute_error: 16.4842
# Epoch 99/100
# 8/8 [==============================] - 0s 12ms/step - loss: 140.7338 - mean_absolute_error: 8.8610 - val_loss: 652.6022 - val_mean_absolute_error: 19.5120
# Epoch 100/100
# 8/8 [==============================] - 0s 10ms/step - loss: 129.5404 - mean_absolute_error: 8.8584 - val_loss: 572.2556 - val_mean_absolute_error: 17.2969
# 8/8 [==============================] - 1s 2ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step

# %%
# Save the model:
#from tensorflow.keras.models import load_model
#model2.save("my_model2")

from tensorflow.keras.models import load_model
import tensorflow as tf

# Load the model back
model2 = load_model("my_model2")

# Suppress the deprecation warning
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# %%
plt.plot(dates_train2, train_predictions2)
plt.plot(dates_train2, Y_train2)
plt.plot(dates_test2, Y_test2)
plt.plot(recursive_dates2, recursive_predictions2)

mae_store2 = []

for obs2, pred2 in zip(Y_test2, recursive_predictions2):
    value2 = abs(obs2 - pred2)
    mae_store2.append(value2)
    
mae2 = sum(mae_store2)/len(mae_store2)


plt.legend(['Training_Predictions','Training_Observations', 
            'Test_Observations', 
           'Recursive_Predictions'])

plt.text(0.02, 0.65, f'MAE: {mae2[0]:.2f}', transform=plt.gca().transAxes, color='blue', fontsize=12)
# Out:
# Text(0.02, 0.65, 'MAE: 25.88')

# %% [markdown]
# - When increasing the size of training data from 80% to 90%, the performance of the model worsens
# - the mae is now $64.82
# - so the model performance seems to be pretty poor

# %% [markdown]
# **I'm curious to visualise the MAE's for these models in the short term**

# %%
mae_values = [mae[0] for mae in mae_store]
mae_values2 = [mae[0] for mae in mae_store2]

# Plot the first set of values
plt.bar(np.arange(len(mae_values)), mae_values, width=bar_width, label='First model')

# Plot the second set of values
plt.bar(np.arange(len(mae_values2)) + bar_width, mae_values2, width=bar_width, label='Second Model')

plt.xlabel('Data Point')
# Uncomment the line below if you want to set custom labels for x-axis
# plt.xticks(np.arange(len(mae_values)) + bar_width/2, ['Date1', 'Date2', 'Date3', 'Date4', 'Date5'], rotation=45)
plt.ylabel('MAE')
plt.title('MAE over time')

plt.legend()  # Add a legend to distinguish between sets

plt.show()

# %% [markdown]
# - What is notable is that the MAE generally increases over time
# - there is a dip in MAE, but this is caused by the true values for Y dipping and so getting closer to the flat line of the predicted values
# - so the model actually performs quite well at predicting the next days close price
# - as you extrapolate further the model performs worse and worse
# - but this makes sense

# %% [markdown]
# # 8. Rolling Model

# %% [markdown]
# - what I want to do now is build a rolling model
# - I will train the model on a period of data
# - then predict the next days close price
# - the model will then move by a date and try and predict the next day
# - I will evaluate how well the model is able to do this

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.optimizers import Adam
from tqdm import tqdm
import numpy as np
import pandas as pd
from copy import deepcopy
from datetime import datetime, timedelta

# %%
# Variables
number_of_data_points = 365 # want a years worth of data in training data
q= 0.8 #proportion of data you want to train model on 
# Decide which stock to analyse
data_set = NVDA
start_date='2022-12-31'
end_date='2024-01-15'
epochs = 10



# Load the raw data
df = cut_raw_data(start_date=start_date, end_date=end_date)

stocks = df['Stock'].unique()

for stock in stocks:
    globals()[f"{stock}"] = df[df['Stock'] == stock].drop('Stock',axis=1)
    

# Make a windowed dataframe - window decides how many days of data are used to predict the next one 
df_windowed = create_window_df(data_set['Close'], window=3)

# Make into a numpy data frame 
dates, X, Y = windowed_to_numpy(df_windowed)

prediction_date = []
observation_store = []
prediction_store =[]

dates_10 = dates
X_10 = X
Y_10 = Y

progress_bar = tqdm(total=len(dates_10), desc="Training Progress")

for start_date in dates_10:
    end_date = start_date + pd.DateOffset(days=number_of_data_points - 1)
    
    
    if end_date >= max(dates_10):
        continue
       
    
    # Cut data for this period
    mask = (dates_10 >= start_date) & (dates_10 <= end_date)
    date_range = dates_10[mask]
    X_temp = X_10[mask]
    Y_temp = Y_10[mask]   
    
    # Split into training and test data
    q_cut = int(len(date_range) * q)

    #Train
    dates_train, X_train, Y_train = date_range[:q_cut], X_temp[:q_cut], Y_temp[:q_cut]

    #Test
    dates_test, X_test, Y_test = date_range[q_cut:], X_temp[q_cut:], Y_temp[q_cut:]



    model_s = Sequential([layers.Input((3,1)), # there are three layers to out input data, because the window has three layers
                   layers.LSTM(64), # number of nuerons in the neural network - this is a good level to prevent overfitting 
                   layers.Dense(32, activation='relu'), # this creates another layer in the NN
                   layers.Dense(32, activation='relu'), # do another
                   layers.Dense(1) # final layer
                   ])

    model_s.compile(loss='mse', # loss means we are trying to minimise the mean squared error
                  optimizer=Adam(learning_rate=0.001), # try this learning rate
                  metrics = ['mean_absolute_error'] # this allows us to see on average how off the model is
                                                    # it makes more sense to interpret this, even if minimising the mean squared error
                 )


    model_s.fit(X_train, Y_train, validation_data=(X_test, Y_test), epochs=epochs ) # runs for 100 times on the training data


    # Predict the next value
    #next_date = dates_test[0] # get the first date in the test data
    #last_window_s = deepcopy(X_train[-1]) # find the last window of dates from training data
    #next_prediction_s = model_s.predict(np.array([last_window_s])).flatten() # predict the dates value 
    
    # By doing above the prediction is always in the past 
    # this needs to take all train/test data and predict beyond this 
    # the larger the dataset used, the better this should be?
    next_date = dates_test[-1] + timedelta(days=1)
    last_window_s = deepcopy(X_test[-1])
    next_prediction_s = model_s.predict(np.array([last_window_s])).flatten()

    # Store values
    prediction_date.append(next_date) # this is the date we are predicting
    observation_store.append(last_window_s[-1]) # this is the prediction the model makes
    prediction_store.append(next_prediction_s) # this is the observed price

# Close the tqdm progress bar
progress_bar.close()
# Out:
# Training Progress:   0%|                                                                       | 0/759 [00:44<?, ?it/s]
# Epoch 1/10
# 7/7 [==============================] - 8s 308ms/step - loss: 129174.2188 - mean_absolute_error: 344.4885 - val_loss: 221923.8281 - val_mean_absolute_error: 470.3374
# Epoch 2/10
# 7/7 [==============================] - 0s 18ms/step - loss: 128868.5625 - mean_absolute_error: 344.0409 - val_loss: 221558.4688 - val_mean_absolute_error: 469.9489
# Epoch 3/10
# 7/7 [==============================] - 0s 21ms/step - loss: 128600.4062 - mean_absolute_error: 343.6527 - val_loss: 221176.6875 - val_mean_absolute_error: 469.5424
# Epoch 4/10
# 7/7 [==============================] - 0s 16ms/step - loss: 128266.9766 - mean_absolute_error: 343.1623 - val_loss: 220568.8281 - val_mean_absolute_error: 468.8944
# Epoch 5/10
# 7/7 [==============================] - 0s 19ms/step - loss: 127717.0469 - mean_absolute_error: 342.3506 - val_loss: 219649.4531 - val_mean_absolute_error: 467.9133
# Epoch 6/10
# 7/7 [==============================] - 0s 19ms/step - loss: 127053.6719 - mean_absolute_error: 341.3908 - val_loss: 218676.0781 - val_mean_absolute_error: 466.8720
# Epoch 7/10
# 7/7 [==============================] - 0s 15ms/step - loss: 126283.7188 - mean_absolute_error: 340.2600 - val_loss: 217491.3750 - val_mean_absolute_error: 465.6010
# Epoch 8/10
# 7/7 [==============================] - 0s 16ms/step - loss: 125290.0625 - mean_absolute_error: 338.7760 - val_loss: 215928.4375 - val_mean_absolute_error: 463.9192
# Epoch 9/10
# 7/7 [==============================] - 0s 17ms/step - loss: 123836.6016 - mean_absolute_error: 336.6327 - val_loss: 213304.8594 - val_mean_absolute_error: 461.0837
# Epoch 10/10
# 7/7 [==============================] - 0s 19ms/step - loss: 121987.6016 - mean_absolute_error: 333.8787 - val_loss: 210761.2812 - val_mean_absolute_error: 458.3155
# 1/1 [==============================] - 1s 1s/step
# Epoch 1/10
# 7/7 [==============================] - 9s 259ms/step - loss: 129412.1875 - mean_absolute_error: 345.0423 - val_loss: 222449.8594 - val_mean_absolute_error: 470.8675
# Epoch 2/10
# 7/7 [==============================] - 0s 18ms/step - loss: 128773.8125 - mean_absolute_error: 344.1294 - val_loss: 221538.8281 - val_mean_absolute_error: 469.8992
# Epoch 3/10
# 7/7 [==============================] - 0s 18ms/step - loss: 128064.3984 - mean_absolute_error: 343.0972 - val_loss: 220437.2188 - val_mean_absolute_error: 468.7254
# Epoch 4/10
# 7/7 [==============================] - 0s 18ms/step - loss: 127152.1797 - mean_absolute_error: 341.7599 - val_loss: 218962.2812 - val_mean_absolute_error: 467.1492
# Epoch 5/10
# 7/7 [==============================] - 0s 16ms/step - loss: 125941.7734 - mean_absolute_error: 339.9646 - val_loss: 216952.7812 - val_mean_absolute_error: 464.9936
# Epoch 6/10
# 7/7 [==============================] - 0s 15ms/step - loss: 124337.2031 - mean_absolute_error: 337.6051 - val_loss: 214483.4844 - val_mean_absolute_error: 462.3304
# Epoch 7/10
# 7/7 [==============================] - 0s 18ms/step - loss: 122187.7188 - mean_absolute_error: 334.3852 - val_loss: 210497.6094 - val_mean_absolute_error: 457.9989
# Epoch 8/10
# 7/7 [==============================] - 0s 17ms/step - loss: 118764.0000 - mean_absolute_error: 329.1817 - val_loss: 204669.7969 - val_mean_absolute_error: 451.5906
# Epoch 9/10
# 7/7 [==============================] - 0s 16ms/step - loss: 114126.1094 - mean_absolute_error: 322.0961 - val_loss: 197790.4688 - val_mean_absolute_error: 443.9083
# Epoch 10/10
# 7/7 [==============================] - 0s 21ms/step - loss: 108795.3828 - mean_absolute_error: 313.7096 - val_loss: 189440.1406 - val_mean_absolute_error: 434.4021
# 1/1 [==============================] - 1s 1s/step
# Epoch 1/10
# 7/7 [==============================] - 9s 262ms/step - loss: 130494.1328 - mean_absolute_error: 346.8468 - val_loss: 225261.7188 - val_mean_absolute_error: 473.8389
# Epoch 2/10
# 7/7 [==============================] - 0s 24ms/step - loss: 130155.7891 - mean_absolute_error: 346.3496 - val_loss: 224795.6094 - val_mean_absolute_error: 473.3467
# Epoch 3/10
# 7/7 [==============================] - 0s 20ms/step - loss: 129784.5781 - mean_absolute_error: 345.8155 - val_loss: 224265.6875 - val_mean_absolute_error: 472.7864
# Epoch 4/10
# 7/7 [==============================] - 0s 19ms/step - loss: 129336.2422 - mean_absolute_error: 345.1503 - val_loss: 223538.3594 - val_mean_absolute_error: 472.0166
# Epoch 5/10
# 7/7 [==============================] - 0s 24ms/step - loss: 128745.2266 - mean_absolute_error: 344.2957 - val_loss: 222543.9375 - val_mean_absolute_error: 470.9615
# Epoch 6/10
# 7/7 [==============================] - 0s 16ms/step - loss: 127893.9219 - mean_absolute_error: 343.0586 - val_loss: 221103.8750 - val_mean_absolute_error: 469.4308
# Epoch 7/10
# 7/7 [==============================] - 0s 14ms/step - loss: 126764.0781 - mean_absolute_error: 341.4159 - val_loss: 219300.3125 - val_mean_absolute_error: 467.5056
# Epoch 8/10
# 7/7 [==============================] - 0s 19ms/step - loss: 125348.3203 - mean_absolute_error: 339.3341 - val_loss: 217214.2188 - val_mean_absolute_error: 465.2695
# Epoch 9/10
# 7/7 [==============================] - 0s 15ms/step - loss: 123780.6094 - mean_absolute_error: 337.0334 - val_loss: 214852.3906 - val_mean_absolute_error: 462.7242
# Epoch 10/10
# 7/7 [==============================] - 0s 17ms/step - loss: 121804.0781 - mean_absolute_error: 334.0757 - val_loss: 211636.6719 - val_mean_absolute_error: 459.2354
# 1/1 [==============================] - 1s 1s/step
# Epoch 1/10
# 7/7 [==============================] - 8s 152ms/step - loss: 131408.2812 - mean_absolute_error: 348.3770 - val_loss: 227895.6406 - val_mean_absolute_error: 476.6252
# Epoch 2/10
# 7/7 [==============================] - 0s 15ms/step - loss: 130750.5781 - mean_absolute_error: 347.4398 - val_loss: 227026.6250 - val_mean_absolute_error: 475.7125
# Epoch 3/10
# 7/7 [==============================] - 0s 13ms/step - loss: 130085.1484 - mean_absolute_error: 346.4905 - val_loss: 226014.7500 - val_mean_absolute_error: 474.6480
# Epoch 4/10
# 7/7 [==============================] - 0s 15ms/step - loss: 129336.3438 - mean_absolute_error: 345.3954 - val_loss: 224968.4375 - val_mean_absolute_error: 473.5441
# Epoch 5/10
# 7/7 [==============================] - 0s 14ms/step - loss: 128435.7734 - mean_absolute_error: 344.0978 - val_loss: 223453.5312 - val_mean_absolute_error: 471.9423
# Epoch 6/10
# 7/7 [==============================] - 0s 14ms/step - loss: 127296.9375 - mean_absolute_error: 342.4124 - val_loss: 221702.8750 - val_mean_absolute_error: 470.0825
# Epoch 7/10
# 7/7 [==============================] - 0s 11ms/step - loss: 125681.0781 - mean_absolute_error: 340.0513 - val_loss: 218780.2188 - val_mean_absolute_error: 466.9650
# Epoch 8/10
# 7/7 [==============================] - 0s 12ms/step - loss: 123528.9688 - mean_absolute_error: 336.8712 - val_loss: 215794.1250 - val_mean_absolute_error: 463.7543
# Epoch 9/10
# 7/7 [==============================] - 0s 23ms/step - loss: 120774.8672 - mean_absolute_error: 332.7255 - val_loss: 210956.9844 - val_mean_absolute_error: 458.5110
# Epoch 10/10
# 7/7 [==============================] - 0s 25ms/step - loss: 117326.0469 - mean_absolute_error: 327.4850 - val_loss: 205715.1719 - val_mean_absolute_error: 452.7565
# 1/1 [==============================] - 1s 907ms/step
# Epoch 1/10
# 7/7 [==============================] - 8s 281ms/step - loss: 132170.4844 - mean_absolute_error: 349.7144 - val_loss: 231062.4375 - val_mean_absolute_error: 479.9484
# Epoch 2/10
# 7/7 [==============================] - 0s 27ms/step - loss: 131941.9375 - mean_absolute_error: 349.3896 - val_loss: 230697.7969 - val_mean_absolute_error: 479.5684
# Epoch 3/10
# 7/7 [==============================] - 0s 24ms/step - loss: 131677.5938 - mean_absolute_error: 349.0113 - val_loss: 230352.9531 - val_mean_absolute_error: 479.2087
# Epoch 4/10
# 7/7 [==============================] - 0s 13ms/step - loss: 131415.1562 - mean_absolute_error: 348.6339 - val_loss: 229968.5312 - val_mean_absolute_error: 478.8074
# Epoch 5/10
# 7/7 [==============================] - 0s 12ms/step - loss: 131114.7656 - mean_absolute_error: 348.2068 - val_loss: 229502.7656 - val_mean_absolute_error: 478.3209
# Epoch 6/10
# 7/7 [==============================] - 0s 23ms/step - loss: 130762.1094 - mean_absolute_error: 347.6917 - val_loss: 228965.5625 - val_mean_absolute_error: 477.7589
# Epoch 7/10
# 7/7 [==============================] - 0s 33ms/step - loss: 130321.1719 - mean_absolute_error: 347.0585 - val_loss: 228265.2969 - val_mean_absolute_error: 477.0253
# Epoch 8/10
# 7/7 [==============================] - 0s 26ms/step - loss: 129691.2031 - mean_absolute_error: 346.1223 - val_loss: 227043.3906 - val_mean_absolute_error: 475.7423
# Epoch 9/10
# 7/7 [==============================] - 0s 24ms/step - loss: 128612.3516 - mean_absolute_error: 344.5804 - val_loss: 225382.7812 - val_mean_absolute_error: 473.9930
# Epoch 10/10
# 7/7 [==============================] - 0s 20ms/step - loss: 127120.9766 - mean_absolute_error: 342.3785 - val_loss: 222698.6250 - val_mean_absolute_error: 471.1545
# 1/1 [==============================] - 1s 1s/step
# Training Progress:   0%|                                                                       | 0/256 [00:57<?, ?it/s]

# %%
prediction_date
# Out:
# [Timestamp('2024-01-06 00:00:00'),
#  Timestamp('2024-01-09 00:00:00'),
#  Timestamp('2024-01-10 00:00:00'),
#  Timestamp('2024-01-11 00:00:00'),
#  Timestamp('2024-01-12 00:00:00')]

# %%
observation_store
# Out:
# [array([479.98], dtype=float32),
#  array([490.97], dtype=float32),
#  array([522.53], dtype=float32),
#  array([531.4], dtype=float32),
#  array([543.5], dtype=float32)]

# %%
prediction_store
# Out:
# [array([12.379508], dtype=float32),
#  array([37.973076], dtype=float32),
#  array([15.358025], dtype=float32),
#  array([24.508558], dtype=float32),
#  array([9.018666], dtype=float32)]

# %%
last_window_s
# Out:
# array([[522.53],
#        [531.4 ],
#        [543.5 ]], dtype=float32)

# %%
next_prediction_s
# Out:
# array([9.018666], dtype=float32)

# %% [markdown]
# - my attempt at building a rollin model has also not been possible
# - the issue I am facing here is that there is a training period, then a validation period when training the model
# - the predicted value sits outside both of these date ranges
# - meaning that there is a significant gap between the last date of the training data and the prediction date
# - this explains why the predictability of the mode is so weak
# - in conclusion, this model and technique has not been effective in predicting future stock prices
